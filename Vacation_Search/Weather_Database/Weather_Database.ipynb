# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
import numpy as np 
from citipy import citipy

# %%
# Generate 2000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['hoa binh', 'pevek', 'lebu', 'tasiilaq', 'rikitea', 'new norfolk', 'severo-kurilsk', 'qaanaaq', 'busselton', 'sentyabrskiy'] Generate 753

# %%
# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']


        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hoa binh
# Processing Record 2 of Set 1 | pevek
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | severo-kurilsk
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 1 | pankrushikha
# Processing Record 12 of Set 1 | nuevitas
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | havoysund
# Processing Record 15 of Set 1 | kieta
# Processing Record 16 of Set 1 | bandarbeyla
# Processing Record 17 of Set 1 | guerrero negro
# Processing Record 18 of Set 1 | longyan
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | chipinge
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | katsuura
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | qaqortoq
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | tuatapere
# Processing Record 30 of Set 1 | margate
# Processing Record 31 of Set 1 | karratha
# Processing Record 32 of Set 1 | guasdualito
# Processing Record 33 of Set 1 | puerto carreno
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | talen
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | boyolangu
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | kutum
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | ode
# Processing Record 43 of Set 1 | hereford
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | laguna
# Processing Record 47 of Set 1 | bathsheba
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | storsteinnes
# Processing Record 1 of Set 2 | luanda
# Processing Record 2 of Set 2 | geraldton
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | meulaboh
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | daxian
# City not found. Skipping...
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | blythe
# Processing Record 10 of Set 2 | biak
# Processing Record 11 of Set 2 | lasa
# Processing Record 12 of Set 2 | chapais
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | coolum beach
# Processing Record 15 of Set 2 | mahebourg
# Processing Record 16 of Set 2 | ballina
# Processing Record 17 of Set 2 | mataura
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | shimoda
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | lata
# Processing Record 24 of Set 2 | saint-pierre
# Processing Record 25 of Set 2 | alexander city
# Processing Record 26 of Set 2 | san cristobal
# Processing Record 27 of Set 2 | klaksvik
# Processing Record 28 of Set 2 | le marin
# Processing Record 29 of Set 2 | nanortalik
# Processing Record 30 of Set 2 | hasaki
# Processing Record 31 of Set 2 | udachnyy
# Processing Record 32 of Set 2 | grindavik
# Processing Record 33 of Set 2 | lerum
# Processing Record 34 of Set 2 | ust-tsilma
# Processing Record 35 of Set 2 | fomboni
# Processing Record 36 of Set 2 | zhaocheng
# City not found. Skipping...
# Processing Record 37 of Set 2 | baft
# Processing Record 38 of Set 2 | saint george
# Processing Record 39 of Set 2 | mao
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | talnakh
# Processing Record 42 of Set 2 | cockburn town
# Processing Record 43 of Set 2 | ponta delgada
# Processing Record 44 of Set 2 | chokwe
# Processing Record 45 of Set 2 | luderitz
# Processing Record 46 of Set 2 | rangpur
# Processing Record 47 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 2 | terrace bay
# Processing Record 49 of Set 2 | flinders
# Processing Record 50 of Set 2 | san patricio
# Processing Record 1 of Set 3 | fairbanks
# Processing Record 2 of Set 3 | praia da vitoria
# Processing Record 3 of Set 3 | bambous virieux
# Processing Record 4 of Set 3 | oktyabrskoye
# Processing Record 5 of Set 3 | ponta do sol
# Processing Record 6 of Set 3 | olafsvik
# Processing Record 7 of Set 3 | kudahuvadhoo
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | kirakira
# Processing Record 10 of Set 3 | mareeba
# Processing Record 11 of Set 3 | mamakan
# Processing Record 12 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | souillac
# Processing Record 15 of Set 3 | carnarvon
# Processing Record 16 of Set 3 | narsaq
# Processing Record 17 of Set 3 | mocuba
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | general roca
# Processing Record 20 of Set 3 | kodiak
# Processing Record 21 of Set 3 | fortuna
# Processing Record 22 of Set 3 | nuuk
# Processing Record 23 of Set 3 | lithakia
# Processing Record 24 of Set 3 | hithadhoo
# Processing Record 25 of Set 3 | gizo
# Processing Record 26 of Set 3 | coquimbo
# Processing Record 27 of Set 3 | chuy
# Processing Record 28 of Set 3 | hofn
# Processing Record 29 of Set 3 | batemans bay
# Processing Record 30 of Set 3 | atar
# Processing Record 31 of Set 3 | betioky
# Processing Record 32 of Set 3 | khatanga
# Processing Record 33 of Set 3 | maglajani
# Processing Record 34 of Set 3 | conde
# Processing Record 35 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 3 | cleland
# Processing Record 37 of Set 3 | lavrentiya
# Processing Record 38 of Set 3 | asau
# Processing Record 39 of Set 3 | basco
# Processing Record 40 of Set 3 | avarua
# Processing Record 41 of Set 3 | nirgua
# Processing Record 42 of Set 3 | kaitangata
# Processing Record 43 of Set 3 | abancay
# Processing Record 44 of Set 3 | shush
# Processing Record 45 of Set 3 | kismayo
# Processing Record 46 of Set 3 | vallenar
# Processing Record 47 of Set 3 | turkistan
# Processing Record 48 of Set 3 | leshan
# Processing Record 49 of Set 3 | canmore
# Processing Record 50 of Set 3 | jishou
# Processing Record 1 of Set 4 | ouadda
# Processing Record 2 of Set 4 | husavik
# Processing Record 3 of Set 4 | eureka
# Processing Record 4 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 4 | sao joao da barra
# Processing Record 7 of Set 4 | ilulissat
# Processing Record 8 of Set 4 | formiga
# Processing Record 9 of Set 4 | marawi
# Processing Record 10 of Set 4 | ruteng
# Processing Record 11 of Set 4 | magdagachi
# Processing Record 12 of Set 4 | tazmalt
# Processing Record 13 of Set 4 | atuona
# Processing Record 14 of Set 4 | maniitsoq
# Processing Record 15 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 4 | pisco
# Processing Record 18 of Set 4 | carauari
# Processing Record 19 of Set 4 | opportunity
# Processing Record 20 of Set 4 | machilipatnam
# Processing Record 21 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 4 | alyangula
# Processing Record 23 of Set 4 | eldikan
# City not found. Skipping...
# Processing Record 24 of Set 4 | yenagoa
# Processing Record 25 of Set 4 | ekhabi
# Processing Record 26 of Set 4 | urumqi
# Processing Record 27 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 4 | wanning
# Processing Record 29 of Set 4 | torbay
# Processing Record 30 of Set 4 | northam
# Processing Record 31 of Set 4 | wanaka
# Processing Record 32 of Set 4 | zyryanka
# Processing Record 33 of Set 4 | darovskoy
# Processing Record 34 of Set 4 | miles city
# Processing Record 35 of Set 4 | sampit
# Processing Record 36 of Set 4 | victoria
# Processing Record 37 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 38 of Set 4 | katangli
# Processing Record 39 of Set 4 | slobodskoy
# Processing Record 40 of Set 4 | tahoua
# Processing Record 41 of Set 4 | marsh harbour
# Processing Record 42 of Set 4 | awbari
# Processing Record 43 of Set 4 | kodinsk
# Processing Record 44 of Set 4 | asayita
# City not found. Skipping...
# Processing Record 45 of Set 4 | arlit
# Processing Record 46 of Set 4 | touros
# Processing Record 47 of Set 4 | antofagasta
# Processing Record 48 of Set 4 | decatur
# Processing Record 49 of Set 4 | ocho rios
# Processing Record 50 of Set 4 | ambon
# Processing Record 1 of Set 5 | muros
# Processing Record 2 of Set 5 | severodvinsk
# Processing Record 3 of Set 5 | saldanha
# Processing Record 4 of Set 5 | yellowknife
# Processing Record 5 of Set 5 | bangkalan
# Processing Record 6 of Set 5 | vila velha
# Processing Record 7 of Set 5 | komsomolskiy
# Processing Record 8 of Set 5 | nome
# Processing Record 9 of Set 5 | dingle
# Processing Record 10 of Set 5 | ostrovnoy
# Processing Record 11 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 5 | vorontsovka
# Processing Record 13 of Set 5 | mojo
# Processing Record 14 of Set 5 | palmer
# Processing Record 15 of Set 5 | airai
# Processing Record 16 of Set 5 | vanimo
# Processing Record 17 of Set 5 | merauke
# Processing Record 18 of Set 5 | ghanzi
# Processing Record 19 of Set 5 | port lincoln
# Processing Record 20 of Set 5 | cherskiy
# Processing Record 21 of Set 5 | holme
# Processing Record 22 of Set 5 | huarmey
# Processing Record 23 of Set 5 | itoman
# Processing Record 24 of Set 5 | adrar
# Processing Record 25 of Set 5 | kalmunai
# Processing Record 26 of Set 5 | saint-georges
# Processing Record 27 of Set 5 | henties bay
# Processing Record 28 of Set 5 | isangel
# Processing Record 29 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 5 | ginir
# Processing Record 31 of Set 5 | mayumba
# Processing Record 32 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 33 of Set 5 | baykalsk
# Processing Record 34 of Set 5 | pangnirtung
# Processing Record 35 of Set 5 | mangaluru
# Processing Record 36 of Set 5 | mount gambier
# Processing Record 37 of Set 5 | ulaangom
# Processing Record 38 of Set 5 | bonfim
# Processing Record 39 of Set 5 | champasak
# Processing Record 40 of Set 5 | maryborough
# Processing Record 41 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 5 | talaya
# Processing Record 43 of Set 5 | bengkulu
# Processing Record 44 of Set 5 | maketu
# Processing Record 45 of Set 5 | ollioules
# Processing Record 46 of Set 5 | tarabuco
# Processing Record 47 of Set 5 | east london
# Processing Record 48 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 5 | clyde river
# Processing Record 50 of Set 5 | viamao
# Processing Record 1 of Set 6 | coihaique
# Processing Record 2 of Set 6 | georgetown
# Processing Record 3 of Set 6 | najran
# Processing Record 4 of Set 6 | butterworth
# Processing Record 5 of Set 6 | cabra
# Processing Record 6 of Set 6 | ishigaki
# Processing Record 7 of Set 6 | umm lajj
# Processing Record 8 of Set 6 | newport
# Processing Record 9 of Set 6 | martapura
# Processing Record 10 of Set 6 | cordoba
# Processing Record 11 of Set 6 | pundaguitan
# Processing Record 12 of Set 6 | kavieng
# Processing Record 13 of Set 6 | sibolga
# Processing Record 14 of Set 6 | janauba
# Processing Record 15 of Set 6 | maiduguri
# Processing Record 16 of Set 6 | tairua
# Processing Record 17 of Set 6 | novouzensk
# Processing Record 18 of Set 6 | arman
# Processing Record 19 of Set 6 | taburao
# City not found. Skipping...
# Processing Record 20 of Set 6 | takoradi
# Processing Record 21 of Set 6 | fort nelson
# Processing Record 22 of Set 6 | hay river
# Processing Record 23 of Set 6 | porto torres
# Processing Record 24 of Set 6 | ugoofaaru
# Processing Record 25 of Set 6 | leningradskiy
# Processing Record 26 of Set 6 | norman wells
# Processing Record 27 of Set 6 | vao
# Processing Record 28 of Set 6 | kloulklubed
# Processing Record 29 of Set 6 | tazovskiy
# Processing Record 30 of Set 6 | muroto
# Processing Record 31 of Set 6 | codajas
# Processing Record 32 of Set 6 | darhan
# Processing Record 33 of Set 6 | morro da fumaca
# Processing Record 34 of Set 6 | maracacume
# Processing Record 35 of Set 6 | la ronge
# Processing Record 36 of Set 6 | provideniya
# Processing Record 37 of Set 6 | plymouth
# Processing Record 38 of Set 6 | saskylakh
# Processing Record 39 of Set 6 | saravena
# Processing Record 40 of Set 6 | chokurdakh
# Processing Record 41 of Set 6 | taoudenni
# Processing Record 42 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 6 | antalaha
# Processing Record 44 of Set 6 | nangong
# Processing Record 45 of Set 6 | grenaa
# Processing Record 46 of Set 6 | richards bay
# Processing Record 47 of Set 6 | high level
# Processing Record 48 of Set 6 | zhigansk
# Processing Record 49 of Set 6 | waddan
# Processing Record 50 of Set 6 | safakulevo
# Processing Record 1 of Set 7 | samarai
# Processing Record 2 of Set 7 | tigre
# Processing Record 3 of Set 7 | havre-saint-pierre
# Processing Record 4 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 5 of Set 7 | kruisfontein
# Processing Record 6 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 7 | vetlanda
# Processing Record 8 of Set 7 | zapolyarnyy
# Processing Record 9 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 7 | batsfjord
# Processing Record 11 of Set 7 | carluke
# Processing Record 12 of Set 7 | lalmohan
# Processing Record 13 of Set 7 | viedma
# Processing Record 14 of Set 7 | lishui
# Processing Record 15 of Set 7 | umba
# Processing Record 16 of Set 7 | oktyabrskiy
# Processing Record 17 of Set 7 | altay
# Processing Record 18 of Set 7 | de aar
# Processing Record 19 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 7 | walvis bay
# Processing Record 21 of Set 7 | mogok
# Processing Record 22 of Set 7 | tiarei
# Processing Record 23 of Set 7 | comodoro rivadavia
# Processing Record 24 of Set 7 | alice springs
# Processing Record 25 of Set 7 | lardos
# Processing Record 26 of Set 7 | rocha
# Processing Record 27 of Set 7 | tautira
# Processing Record 28 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 29 of Set 7 | cody
# Processing Record 30 of Set 7 | kiama
# Processing Record 31 of Set 7 | cabo san lucas
# Processing Record 32 of Set 7 | paucartambo
# City not found. Skipping...
# Processing Record 33 of Set 7 | woodstock
# Processing Record 34 of Set 7 | te anau
# Processing Record 35 of Set 7 | sitka
# Processing Record 36 of Set 7 | aasiaat
# Processing Record 37 of Set 7 | mandan
# Processing Record 38 of Set 7 | la palma
# Processing Record 39 of Set 7 | dorado
# Processing Record 40 of Set 7 | esil
# Processing Record 41 of Set 7 | iqaluit
# Processing Record 42 of Set 7 | itaberai
# Processing Record 43 of Set 7 | mount isa
# Processing Record 44 of Set 7 | riyadh
# Processing Record 45 of Set 7 | cap-aux-meules
# Processing Record 46 of Set 7 | sanming
# Processing Record 47 of Set 7 | trinidad
# Processing Record 48 of Set 7 | formosa
# Processing Record 49 of Set 7 | palana
# Processing Record 50 of Set 7 | karasjok
# Processing Record 1 of Set 8 | atbasar
# Processing Record 2 of Set 8 | boa vista
# Processing Record 3 of Set 8 | envira
# Processing Record 4 of Set 8 | nishihara
# Processing Record 5 of Set 8 | stornoway
# Processing Record 6 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 8 | necochea
# Processing Record 8 of Set 8 | tangjiazhuang
# Processing Record 9 of Set 8 | padang
# Processing Record 10 of Set 8 | makakilo city
# Processing Record 11 of Set 8 | baijiantan
# Processing Record 12 of Set 8 | broken hill
# Processing Record 13 of Set 8 | toktogul
# Processing Record 14 of Set 8 | svencionys
# Processing Record 15 of Set 8 | surt
# Processing Record 16 of Set 8 | voznesenskoye
# Processing Record 17 of Set 8 | naifaru
# Processing Record 18 of Set 8 | esperance
# Processing Record 19 of Set 8 | atambua
# Processing Record 20 of Set 8 | pakxan
# Processing Record 21 of Set 8 | whitehorse
# Processing Record 22 of Set 8 | blind river
# Processing Record 23 of Set 8 | tura
# Processing Record 24 of Set 8 | puerto escondido
# Processing Record 25 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 8 | cilegon
# Processing Record 27 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 28 of Set 8 | livingstonia
# Processing Record 29 of Set 8 | constitucion
# Processing Record 30 of Set 8 | vurgun
# Processing Record 31 of Set 8 | zarya
# Processing Record 32 of Set 8 | verkhnevilyuysk
# Processing Record 33 of Set 8 | pacific grove
# Processing Record 34 of Set 8 | balkhash
# Processing Record 35 of Set 8 | itarema
# Processing Record 36 of Set 8 | baisha
# Processing Record 37 of Set 8 | sherbakul
# Processing Record 38 of Set 8 | laguna de duero
# Processing Record 39 of Set 8 | muisne
# Processing Record 40 of Set 8 | acapulco
# Processing Record 41 of Set 8 | nouna
# Processing Record 42 of Set 8 | ashoknagar
# Processing Record 43 of Set 8 | bundaberg
# Processing Record 44 of Set 8 | gisborne
# Processing Record 45 of Set 8 | aklavik
# Processing Record 46 of Set 8 | milosesti
# Processing Record 47 of Set 8 | puerto del rosario
# Processing Record 48 of Set 8 | iberia
# Processing Record 49 of Set 8 | izazi
# Processing Record 50 of Set 8 | uhlove
# Processing Record 1 of Set 9 | agirish
# Processing Record 2 of Set 9 | hamilton
# Processing Record 3 of Set 9 | matamoros
# Processing Record 4 of Set 9 | provost
# Processing Record 5 of Set 9 | bo phloi
# Processing Record 6 of Set 9 | adre
# Processing Record 7 of Set 9 | tammisaari
# Processing Record 8 of Set 9 | weyburn
# Processing Record 9 of Set 9 | lagoa
# Processing Record 10 of Set 9 | copiapo
# Processing Record 11 of Set 9 | san andres
# Processing Record 12 of Set 9 | taltal
# Processing Record 13 of Set 9 | nemuro
# Processing Record 14 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 9 | maunabo
# Processing Record 16 of Set 9 | sisimiut
# Processing Record 17 of Set 9 | sorong
# Processing Record 18 of Set 9 | khomutovo
# Processing Record 19 of Set 9 | beringovskiy
# Processing Record 20 of Set 9 | yulara
# Processing Record 21 of Set 9 | cidreira
# Processing Record 22 of Set 9 | hit
# Processing Record 23 of Set 9 | hoquiam
# Processing Record 24 of Set 9 | poum
# Processing Record 25 of Set 9 | imeni poliny osipenko
# Processing Record 26 of Set 9 | los llanos de aridane
# Processing Record 27 of Set 9 | medina
# Processing Record 28 of Set 9 | babu
# Processing Record 29 of Set 9 | pokhara
# Processing Record 30 of Set 9 | poretskoye
# Processing Record 31 of Set 9 | roebourne
# Processing Record 32 of Set 9 | marondera
# Processing Record 33 of Set 9 | gat
# Processing Record 34 of Set 9 | kempele
# Processing Record 35 of Set 9 | rio grande
# Processing Record 36 of Set 9 | corbelia
# Processing Record 37 of Set 9 | skeldon
# Processing Record 38 of Set 9 | keetmanshoop
# Processing Record 39 of Set 9 | namatanai
# Processing Record 40 of Set 9 | kropotkin
# Processing Record 41 of Set 9 | san rafael
# Processing Record 42 of Set 9 | poso
# Processing Record 43 of Set 9 | cachoeiras de macacu
# Processing Record 44 of Set 9 | tromso
# Processing Record 45 of Set 9 | neustadt
# Processing Record 46 of Set 9 | bilibino
# Processing Record 47 of Set 9 | taseyevo
# Processing Record 48 of Set 9 | vila franca do campo
# Processing Record 49 of Set 9 | zhangjiakou
# Processing Record 50 of Set 9 | yangjiang
# Processing Record 1 of Set 10 | corn island
# Processing Record 2 of Set 10 | helong
# Processing Record 3 of Set 10 | damghan
# Processing Record 4 of Set 10 | mehamn
# Processing Record 5 of Set 10 | port hawkesbury
# Processing Record 6 of Set 10 | tagusao
# Processing Record 7 of Set 10 | san jose
# Processing Record 8 of Set 10 | stettler
# Processing Record 9 of Set 10 | champerico
# Processing Record 10 of Set 10 | goulburn
# Processing Record 11 of Set 10 | tilichiki
# Processing Record 12 of Set 10 | dickson
# Processing Record 13 of Set 10 | baruun-urt
# Processing Record 14 of Set 10 | alofi
# Processing Record 15 of Set 10 | sao felix do xingu
# Processing Record 16 of Set 10 | yangshe
# Processing Record 17 of Set 10 | weligama
# Processing Record 18 of Set 10 | vestmannaeyjar
# Processing Record 19 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 21 of Set 10 | cacoal
# Processing Record 22 of Set 10 | scottsbluff
# Processing Record 23 of Set 10 | nelson bay
# Processing Record 24 of Set 10 | waingapu
# Processing Record 25 of Set 10 | labuhan
# Processing Record 26 of Set 10 | honiara
# Processing Record 27 of Set 10 | salo
# Processing Record 28 of Set 10 | cabedelo
# Processing Record 29 of Set 10 | plettenberg bay
# Processing Record 30 of Set 10 | benguela
# Processing Record 31 of Set 10 | sur
# Processing Record 32 of Set 10 | andapa
# Processing Record 33 of Set 10 | maraa
# Processing Record 34 of Set 10 | padilla
# Processing Record 35 of Set 10 | cayce
# Processing Record 36 of Set 10 | ahipara
# Processing Record 37 of Set 10 | rapar
# Processing Record 38 of Set 10 | bethel
# Processing Record 39 of Set 10 | fukue
# Processing Record 40 of Set 10 | salekhard
# Processing Record 41 of Set 10 | tupancireta
# Processing Record 42 of Set 10 | kjollefjord
# Processing Record 43 of Set 10 | lahat
# Processing Record 44 of Set 10 | tupelo
# Processing Record 45 of Set 10 | ossora
# Processing Record 46 of Set 10 | cuapiaxtla
# Processing Record 47 of Set 10 | port-cartier
# Processing Record 48 of Set 10 | sinnamary
# Processing Record 49 of Set 10 | kokstad
# Processing Record 50 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 11 | kahului
# Processing Record 2 of Set 11 | clarence town
# Processing Record 3 of Set 11 | monster
# Processing Record 4 of Set 11 | cambridge
# Processing Record 5 of Set 11 | manuk mangkaw
# Processing Record 6 of Set 11 | phagwara
# Processing Record 7 of Set 11 | sheridan
# Processing Record 8 of Set 11 | bairnsdale
# Processing Record 9 of Set 11 | san quintin
# Processing Record 10 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 11 | aswan
# Processing Record 12 of Set 11 | kavaratti
# Processing Record 13 of Set 11 | linda
# Processing Record 14 of Set 11 | zeulenroda
# Processing Record 15 of Set 11 | salinas
# Processing Record 16 of Set 11 | moussoro
# Processing Record 17 of Set 11 | cravo norte
# Processing Record 18 of Set 11 | zaraza
# Processing Record 19 of Set 11 | haines junction
# Processing Record 20 of Set 11 | uglegorsk
# Processing Record 21 of Set 11 | villarrica
# Processing Record 22 of Set 11 | saint-francois
# Processing Record 23 of Set 11 | cap malheureux
# Processing Record 24 of Set 11 | diamantino
# Processing Record 25 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 26 of Set 11 | fengzhen
# Processing Record 27 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 28 of Set 11 | bubaque
# Processing Record 29 of Set 11 | springdale
# Processing Record 30 of Set 11 | terney
# Processing Record 31 of Set 11 | amahai
# Processing Record 32 of Set 11 | axim
# Processing Record 33 of Set 11 | spisska bela
# Processing Record 34 of Set 11 | camana
# Processing Record 35 of Set 11 | dukat
# Processing Record 36 of Set 11 | avera
# Processing Record 37 of Set 11 | oron
# Processing Record 38 of Set 11 | alihe
# Processing Record 39 of Set 11 | tiksi
# Processing Record 40 of Set 11 | tibu
# Processing Record 41 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 43 of Set 11 | marsa matruh
# Processing Record 44 of Set 11 | gornopravdinsk
# Processing Record 45 of Set 11 | jizan
# Processing Record 46 of Set 11 | lucapa
# Processing Record 47 of Set 11 | porirua
# Processing Record 48 of Set 11 | narrabri
# Processing Record 49 of Set 11 | opuwo
# Processing Record 50 of Set 11 | buchanan
# Processing Record 1 of Set 12 | tolga
# Processing Record 2 of Set 12 | salalah
# Processing Record 3 of Set 12 | ngunguru
# Processing Record 4 of Set 12 | dehui
# Processing Record 5 of Set 12 | rawson
# Processing Record 6 of Set 12 | broome
# Processing Record 7 of Set 12 | hurricane
# Processing Record 8 of Set 12 | faya
# Processing Record 9 of Set 12 | ulladulla
# Processing Record 10 of Set 12 | chaumont
# Processing Record 11 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 12 | cayenne
# Processing Record 13 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 12 | kolyvan
# Processing Record 15 of Set 12 | prieska
# Processing Record 16 of Set 12 | hirara
# Processing Record 17 of Set 12 | trat
# Processing Record 18 of Set 12 | bam
# Processing Record 19 of Set 12 | sarai
# Processing Record 20 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 21 of Set 12 | qasigiannguit
# Processing Record 22 of Set 12 | hambantota
# Processing Record 23 of Set 12 | togur
# Processing Record 24 of Set 12 | palkaka
# City not found. Skipping...
# Processing Record 25 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 12 | camapua
# Processing Record 27 of Set 12 | saint-paul
# Processing Record 28 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 29 of Set 12 | bitung
# Processing Record 30 of Set 12 | yamethin
# Processing Record 31 of Set 12 | faanui
# Processing Record 32 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 33 of Set 12 | khandyga
# Processing Record 34 of Set 12 | lokoja
# Processing Record 35 of Set 12 | alta floresta
# Processing Record 36 of Set 12 | caravelas
# Processing Record 37 of Set 12 | sobolevo
# Processing Record 38 of Set 12 | progreso
# Processing Record 39 of Set 12 | port blair
# Processing Record 40 of Set 12 | shizuishan
# Processing Record 41 of Set 12 | catumbela
# Processing Record 42 of Set 12 | illela
# Processing Record 43 of Set 12 | lodwar
# Processing Record 44 of Set 12 | poya
# Processing Record 45 of Set 12 | ikom
# Processing Record 46 of Set 12 | kayerkan
# Processing Record 47 of Set 12 | taunggyi
# Processing Record 48 of Set 12 | wajir
# Processing Record 49 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 50 of Set 12 | kroya
# Processing Record 1 of Set 13 | belize
# Processing Record 2 of Set 13 | dunedin
# Processing Record 3 of Set 13 | mount vernon
# Processing Record 4 of Set 13 | shenkursk
# Processing Record 5 of Set 13 | nouadhibou
# Processing Record 6 of Set 13 | carutapera
# Processing Record 7 of Set 13 | ilam
# Processing Record 8 of Set 13 | strezhevoy
# Processing Record 9 of Set 13 | lebowakgomo
# Processing Record 10 of Set 13 | pechenga
# Processing Record 11 of Set 13 | bagumbayan
# Processing Record 12 of Set 13 | saint-augustin
# Processing Record 13 of Set 13 | vaitape
# Processing Record 14 of Set 13 | kikwit
# Processing Record 15 of Set 13 | conway
# Processing Record 16 of Set 13 | aras
# Processing Record 17 of Set 13 | lefka
# Processing Record 18 of Set 13 | ofunato
# Processing Record 19 of Set 13 | filingue
# Processing Record 20 of Set 13 | kirkwall
# Processing Record 21 of Set 13 | sao filipe
# Processing Record 22 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 23 of Set 13 | george town
# Processing Record 24 of Set 13 | presidencia roque saenz pena
# Processing Record 25 of Set 13 | alamosa
# Processing Record 26 of Set 13 | ketchikan
# Processing Record 27 of Set 13 | rorvik
# Processing Record 28 of Set 13 | singaraja
# Processing Record 29 of Set 13 | awjilah
# Processing Record 30 of Set 13 | sept-iles
# Processing Record 31 of Set 13 | kysyl-syr
# Processing Record 32 of Set 13 | blackfoot
# Processing Record 33 of Set 13 | kupang
# Processing Record 34 of Set 13 | diffa
# Processing Record 35 of Set 13 | ewa beach
# Processing Record 36 of Set 13 | ulverstone
# Processing Record 37 of Set 13 | chulym
# Processing Record 38 of Set 13 | navahrudak
# Processing Record 39 of Set 13 | lorengau
# Processing Record 40 of Set 13 | natal
# Processing Record 41 of Set 13 | dubenskiy
# City not found. Skipping...
# Processing Record 42 of Set 13 | astana
# Processing Record 43 of Set 13 | manokwari
# Processing Record 44 of Set 13 | leh
# Processing Record 45 of Set 13 | tabuk
# Processing Record 46 of Set 13 | gejiu
# Processing Record 47 of Set 13 | lufilufi
# Processing Record 48 of Set 13 | caluquembe
# Processing Record 49 of Set 13 | medicine hat
# Processing Record 50 of Set 13 | namibe
# Processing Record 1 of Set 14 | rio verde de mato grosso
# Processing Record 2 of Set 14 | poro
# Processing Record 3 of Set 14 | qeshm
# Processing Record 4 of Set 14 | yerbogachen
# Processing Record 5 of Set 14 | bairiki
# Processing Record 6 of Set 14 | japura
# Processing Record 7 of Set 14 | teya
# Processing Record 8 of Set 14 | hammerfest
# Processing Record 9 of Set 14 | shaoyang
# Processing Record 10 of Set 14 | talca
# Processing Record 11 of Set 14 | tupik
# Processing Record 12 of Set 14 | suntar
# Processing Record 13 of Set 14 | tabas
# Processing Record 14 of Set 14 | tigil
# Processing Record 15 of Set 14 | providencia
# Processing Record 16 of Set 14 | panama city
# Processing Record 17 of Set 14 | amarante do maranhao
# Processing Record 18 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 14 | santiago del estero
# Processing Record 20 of Set 14 | maumere
# Processing Record 21 of Set 14 | lompoc
# Processing Record 22 of Set 14 | north branch
# Processing Record 23 of Set 14 | polunochnoye
# Processing Record 24 of Set 14 | fowa
# Processing Record 25 of Set 14 | port macquarie
# Processing Record 26 of Set 14 | stolin
# Processing Record 27 of Set 14 | beloha
# Processing Record 28 of Set 14 | matagami
# Processing Record 29 of Set 14 | luwuk
# Processing Record 30 of Set 14 | enid
# Processing Record 31 of Set 14 | verkhnyaya inta
# Processing Record 32 of Set 14 | dhidhdhoo
# Processing Record 33 of Set 14 | si chiang mai
# Processing Record 34 of Set 14 | nyurba
# Processing Record 35 of Set 14 | smithers
# Processing Record 36 of Set 14 | nalut
# Processing Record 37 of Set 14 | agadez
# Processing Record 38 of Set 14 | sergeyevka
# Processing Record 39 of Set 14 | port hardy
# Processing Record 40 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 41 of Set 14 | bayanday
# Processing Record 42 of Set 14 | san carlos de bariloche
# Processing Record 43 of Set 14 | owatonna
# Processing Record 44 of Set 14 | salisbury
# Processing Record 45 of Set 14 | bose
# Processing Record 46 of Set 14 | erenhot
# Processing Record 47 of Set 14 | shulan
# Processing Record 48 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 49 of Set 14 | kuloy
# Processing Record 50 of Set 14 | mandya
# Processing Record 1 of Set 15 | lat yao
# Processing Record 2 of Set 15 | flint
# Processing Record 3 of Set 15 | santa cruz de la palma
# Processing Record 4 of Set 15 | mengcheng
# Processing Record 5 of Set 15 | reconquista
# Processing Record 6 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 7 of Set 15 | jiayuguan
# Processing Record 8 of Set 15 | dwarka
# Processing Record 9 of Set 15 | sistranda
# Processing Record 10 of Set 15 | sandnessjoen
# Processing Record 11 of Set 15 | yar-sale
# Processing Record 12 of Set 15 | stillwater
# Processing Record 13 of Set 15 | ponerihouen
# Processing Record 14 of Set 15 | yelan-koleno
# Processing Record 15 of Set 15 | meiktila
# Processing Record 16 of Set 15 | chara
# Processing Record 17 of Set 15 | rio gallegos
# Processing Record 18 of Set 15 | tahe
# Processing Record 19 of Set 15 | luocheng
# Processing Record 20 of Set 15 | south venice
# Processing Record 21 of Set 15 | abha
# Processing Record 22 of Set 15 | cairns
# Processing Record 23 of Set 15 | san vicente
# Processing Record 24 of Set 15 | codrington
# Processing Record 25 of Set 15 | kailua
# Processing Record 26 of Set 15 | balaguer
# Processing Record 27 of Set 15 | palauig
# Processing Record 28 of Set 15 | greeneville
# Processing Record 29 of Set 15 | vardo
# Processing Record 30 of Set 15 | dong hoi
# Processing Record 31 of Set 15 | quatre cocos
# Processing Record 32 of Set 15 | verkhozim
# Processing Record 33 of Set 15 | kulhudhuffushi
# Processing Record 34 of Set 15 | khorinsk
# Processing Record 35 of Set 15 | gillette
# Processing Record 36 of Set 15 | anadyr
# Processing Record 37 of Set 15 | bonavista
# Processing Record 38 of Set 15 | gomel
# Processing Record 39 of Set 15 | ginda
# Processing Record 40 of Set 15 | korla
# Processing Record 41 of Set 15 | forbes
# Processing Record 42 of Set 15 | batticaloa
# Processing Record 43 of Set 15 | rundu
# Processing Record 44 of Set 15 | ruston
# Processing Record 45 of Set 15 | pompeu
# Processing Record 46 of Set 15 | morondava
# Processing Record 47 of Set 15 | lashio
# Processing Record 48 of Set 15 | rosetta
# Processing Record 49 of Set 15 | kastamonu
# Processing Record 50 of Set 15 | tessalit
# Processing Record 1 of Set 16 | pringsewu
# Processing Record 2 of Set 16 | saint anthony
# Processing Record 3 of Set 16 | kitimat
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 698

# %%
#Save the new DataFrame as a CSV file
city_data_df = pd.DataFrame(city_data)
city_data_df.to_csv(path_or_buf='Weather_Database/WeatherPy_database.csv', index_label='City_ID')
